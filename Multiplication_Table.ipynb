# %% [markdown]
# <a href="https://colab.research.google.com/github/traumathized/PythonBasics/blob/main/Multiplication_Table.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Take a number from user.
#Print its multiplication table up to 10.

number = int(input("Enter a number: "))

for i in range(1, 11):
    print(number, "x", i, "=", number * i)
