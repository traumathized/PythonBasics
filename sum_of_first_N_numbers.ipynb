# %% [markdown]
# <a href="https://colab.research.google.com/github/traumathized/PythonBasics/blob/main/sum_of_first_N_numbers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Enter a number: "))

total = 0

for i in range(1, n + 1):
    total = total + i

print("Sum of first", n, "numbers is:", total)
# Out:
# Enter a number: 5
# Sum of first 5 numbers is: 15
