# %% [markdown]
# <a href="https://colab.research.google.com/github/traumathized/PythonBasics/blob/main/Largest_of_two_numbers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Take two numbers from user
#Print which number is greater
#If both are equal → print "Both are equal"

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

if num1 > num2:
    print("First number is greater")
elif num2 > num1:
    print("Second number is greater")
else:
    print("Both numbers are equal")
# Out:
# Enter first number: 6
# Enter second number: 7
# Second number is greater
