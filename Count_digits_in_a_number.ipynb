# %% [markdown]
# <a href="https://colab.research.google.com/github/traumathized/PythonBasics/blob/main/Count_digits_in_a_number.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
number = int(input("Enter a number: "))

count = 0

while number != 0:
    number = number // 10
    count = count + 1

print("Total digits:", count)
# Out:
# Enter a number: 8500
# Total digits: 4
